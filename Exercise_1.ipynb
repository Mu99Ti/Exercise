# %% [markdown]
# # Question 1

# %%
Dict = {'data1': -10,'data2': 300,'data3': 239}
sum(Dict.values())
# Out:
# 529

# %% [markdown]
# # Question 2

# %%
my_list = ['c','o','m','p','u','t','e','r',]
result = []
result.append(my_list[0])
result.append(my_list[2])
result.append(my_list[3])
a = ''.join(result)
a = a.upper()
my_course = '(Python for Economics)'
print(a + my_course)
# Out:
# CMP(Python for Economics)

# %% [markdown]
# # Question 3

# %%
x, y, z=input('input three numbers to calculate the average').split()
average=(int(x)+int(y)+int(z))/3
print(('average=')+str(average))
# Out:
# input three numbers to calculate the average4589 857398568 423647567
# average=427016908.0

# %% [markdown]
# # Question 4

# %%
x=30 #days in each month
y=x*24 #hours
z=y*60 #minutes
w=z*60 #seconds
print('in each month we have {} hours, {} minutes and {} seconds'.format(y,z,w))
# Out:
# in each month we have 720 hours, 43200 minutes and 2592000 seconds

# %% [markdown]
# # Question 5

# %%
x=int(input('input hour to convert to weeks, days and hours'))
y=x//168 #calculating weeks
z=x%168
w=z//24 #calculating days
m=z%24 #calculating hours
print('{} weeks and {} days and {} hours'.format(y,w,m))
# Out:
# input hour to convert to weeks, days and hours3434
# 20 weeks and 3 days and 2 hours
